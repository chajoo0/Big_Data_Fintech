# %%
# 보드 플롯을 그리는 예
import matplotlib as mpl

# pyplot 모듈
import matplotlib.pyplot as plt

# %%
# 기존 설정값 확인, where RC stands for run commands 
import matplotlib as mpl
print(mpl.rcParams)
# Out:
# _internal.classic_mode: False
# agg.path.chunksize: 0
# animation.avconv_args: []
# animation.avconv_path: avconv
# animation.bitrate: -1
# animation.codec: h264
# animation.convert_args: []
# animation.convert_path: convert
# animation.embed_limit: 20.0
# animation.ffmpeg_args: []
# animation.ffmpeg_path: ffmpeg
# animation.frame_format: png
# animation.html: none
# animation.html_args: []
# animation.writer: ffmpeg
# axes.autolimit_mode: data
# axes.axisbelow: line
# axes.edgecolor: k
# axes.facecolor: w
# axes.formatter.limits: [-7, 7]
# axes.formatter.min_exponent: 0
# axes.formatter.offset_threshold: 4
# axes.formatter.use_locale: False
# axes.formatter.use_mathtext: False
# axes.formatter.useoffset: True
# axes.grid: False
# axes.grid.axis: both
# axes.grid.which: major
# axes.hold: None
# axes.labelcolor: k
# axes.labelpad: 4.0
# axes.labelsize: medium
# axes.labelweight: normal
# axes.linewidth: 0.8
# ...

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
#선굵기를 10으로
mpl. rcParams['lines.linewidth']= 10

#선종류를 점선으로
mpl. rcParams['lines.linestyle']= '--'

#위 두개를 합쳐보면,
mpl.rc('lines', linewidth=1, linestyle='--')
t= np.arange(0,2*np.pi, 0.1)
plt.figure(1)
plt.plot(t,np.sin(t))
plt.show()

# %%
np.arange(10)
plt.plot(np.arange(10))

# %% [markdown]
# ### 설정파일 설정, 변경

# %%
#설정 저장용 디렉토리를 표시
print(mpl.get_configdir())

#설정 파일 이름을 표시
print(mpl.matplotlib_fname())
# Out:
# C:\Users\renz\.matplotlib
# C:\Users\renz\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
#현재 사용가능한 스타일시트 어떤 것이 있는지 확인 (matplotlibrc를 매번 변경하기 귀찮으니까 이런 theme들을 사용할 수 있음)
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('default')

# %%
plt.plot(np.arange(10))

# %% [markdown]
# ### 그래프에서 한글 사용하기!

# %%
mpl.rcParams['font.family'] = 'NanumGothic'

mpl.rcParams['font.size'] =16

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#(1) 한글 기본 설정(이 스크립트 전체가 영향을 받음)
mpl.rcParams['font.family'] = 'NanumGothic'

#(2) 지정한 곳에서만 한글 설정을 유효하게
font_path = 'C:/Windows/Fonts/NanumGothic.ttf'
font_prop = fm.FontProperties(fname= font_path)
font_prop.set_style('normal')
font_prop.set_size('20')
plt.figure(1)
plt.plot([1,2,3], [2,5,9])

#X축 레이블은 설정(1) 적용
plt.xlabel('한글 X축 레이블')

#Y축은 레이블은 설정(2) 적용
plt.ylabel('한글 Y축 레이블', fontproperties=font_prop)
plt.show()

# %%
x = np.arange(-np.pi, np.pi, 0.1)
y1 = np.sin(x)
y2 = np.cos(x) 
plt.plot(x, y1, label='sin')
plt.plot(x, y2, 'r*', markersize=1, label='cosine')

#각 축의 레이블을 그림
plt.xlabel('X-axis'); 
plt.ylabel('Y-axis')
#범례를 그림
plt.legend(loc='best')
#그리기 실행
plt.show()

# %% [markdown]
# ### Subplots

# %%
import matplotlib.pyplot as plt
#서브 플롯 생성
plt.subplot(2, 3, 1), plt.xticks([]), plt. yticks([])

#서브 플롯에 text 삽입
plt.text(0.5, 0.5, 'subplot(2,3,1)', ha='center', va='center', size=10)
plt.subplot(2, 3, 2), plt.xticks([]), plt. yticks([])
plt.text(0.5, 0.5, 'subplot(2,3,2)', ha='center', va='center', size=10)
plt.subplot(2, 3, 3), plt.xticks([]), plt. yticks([])
plt.text(0.5, 0.5, 'subplot(2,3,3)', ha='center', va='center', size=10)
plt.subplot(2, 3, 4), plt.xticks([]), plt. yticks([])
plt.text(0.5, 0.5, 'subplot(2,3,4)', ha='center', va='center', size=10)
plt.subplot(2, 3, 5), plt.xticks([]), plt. yticks([])
plt.text(0.5, 0.5, 'subplot(2,3,5)', ha='center', va='center', size=10)
plt.subplot(2, 3, 6), plt.xticks([]), plt. yticks([])
plt.text(0.5, 0.5, 'subplot(2,3,6)', ha='center', va='center', size=10)
plt.show()

# %%
import matplotlib.gridspec as gs

G = gs. GridSpec(3,3) 
axes_1 = plt.subplot(G[0, :])

# %%
import matplotlib.gridspec as gs

mpl.rcParams["font.family"] = "NanumGothic"
G = gs.GridSpec(3, 3)
axes_1 = plt.subplot(G[0, :])
plt.xticks([]), plt.yticks([])
plt.text(0.5, 0.5, '속틀1', ha='center', va='center', size = 22)

axes_2 = plt.subplot(G[1, :-1])
x = np. arange(-np.pi, np.pi, 0.1)
y = np. sin(x)
plt.plot(x,y)
plt.text(-0.5, 0, '속틀2', ha = 'center', va = 'center', size = 22)
axes_3 = plt.subplot(G[1:, -1])
plt.xticks([]), plt.yticks([])
plt.text(0.5, 0.5, '속틀3', ha='center', va='center', size = 22)

axes_4 = plt.subplot(G[-1, 0])
plt.xticks([]), plt.yticks([])
plt.text(0.5, 0.5, '속틀4', ha='center', va='center', size = 22)

axes_5 = plt.subplot(G[-1, -2])
plt.xticks([]), plt.yticks([])
plt.text(0.5, 0.5, '속틀5', ha='center', va='center', size = 22)

plt.show()

# %%
print(mpl.font_manager.get_cachedir())
# Out:
# C:\Users\renz\.matplotlib

# %%
#서브 플롯을 2개 나란히 배치
plt.figure(1)
plt.subplot(2,1,1)
x = np.arange(-np.pi, np.pi, 0.1)
plt.plot(x, np.sin(x))
plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

#틀 안에 틀을 배치
plt.axes([0.55, 0.3, 0.3, 0.4])
plt.text(0.5,0.5, 'axes([0.55, 0.3, 0.3, 0.4])', ha='center', va='center')
# Out:
# Text(0.5,0.5,'axes([0.55, 0.3, 0.3, 0.4])')

# %% [markdown]
# ### 등고선

# %%
from matplotlib import cm
from matplotlib.mlab import bivariate_normal
#2차원 메시를 작성
N=200
x = np.linspace(-3.0, 3.0, N)
y = np.linspace(-2.0, 2.0, N)
X, Y = np.meshgrid(x,y)

#2변량 정규 분포로 2차원 분포 데이터를 생성
z = 15* (bivariate_normal(X, Y, 1.0, 1.0, 0.0, 0.0)-bivariate_normal(X, Y, 1.5, 0.5, 1, 1))
# Out:
# C:\Users\renz\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
#   # Remove the CWD from sys.path while we load stuff.

# %%
X,Y
# Out:
# (array([[-3.        , -2.96984925, -2.93969849, ...,  2.93969849,
#           2.96984925,  3.        ],
#         [-3.        , -2.96984925, -2.93969849, ...,  2.93969849,
#           2.96984925,  3.        ],
#         [-3.        , -2.96984925, -2.93969849, ...,  2.93969849,
#           2.96984925,  3.        ],
#         ...,
#         [-3.        , -2.96984925, -2.93969849, ...,  2.93969849,
#           2.96984925,  3.        ],
#         [-3.        , -2.96984925, -2.93969849, ...,  2.93969849,
#           2.96984925,  3.        ],
#         [-3.        , -2.96984925, -2.93969849, ...,  2.93969849,
#           2.96984925,  3.        ]]),
#  array([[-2.        , -2.        , -2.        , ..., -2.        ,
#          -2.        , -2.        ],
#         [-1.9798995 , -1.9798995 , -1.9798995 , ..., -1.9798995 ,
#          -1.9798995 , -1.9798995 ],
#         [-1.95979899, -1.95979899, -1.95979899, ..., -1.95979899,
#          -1.95979899, -1.95979899],
#         ...,
# ...

# %%
#z의 값을 농담값으로 삼아 이미지를 나타냄.
im = plt.imshow(z, interpolation = 'bilinear', origin = 'lower', extent = (-3, 3, -2, 2))

# %%
im = plt.imshow(z, interpolation = 'bilinear', origin = 'lower', extent = (-3, 3, -2, 2))

#등고선 표시
levels = np.arange(-3, 2.5, 0.5)
ctr = plt.contour(z, levels, colors = 'k', origin = 'lower', linewidths = 2, extent=(-3, 3, -2, 2))

#등고선에 레이블 인라인 표시
plt.gca().clabel(ctr, levels, inline=1, colors='black',fmt='%1.1f', fontsize=14)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-73029d8e7cd2> in <module>()
#       6
#       7 #등고선에 레이블 인라인 표시
# ----> 8 plt.gca().clabel(ctr, levels, inline=1, colors='black',fmt='%1.1f', fontsize=14)
#       9
#      10 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in clabel(self, CS, *args, **kwargs)
#    6294
#    6295     def clabel(self, CS, *args, **kwargs):
# -> 6296         return CS.clabel(*args, **kwargs)
#    6297     clabel.__doc__ = mcontour.ContourSet.clabel.__doc__
#    6298
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in clabel(self, *args, **kwargs)
#     175             if len(levels) < len(levlabs):
#     176                 raise ValueError("Specified levels {} don't match available "
# --> 177                                  "levels {}".format(levlabs, self.levels))
#     178         else:
# ...

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

#데이터를 3차원 플롯으로 플로팅
fig = plt.figure(1) 

ax =fig.add_subplot(111, projection ='3d')   

surf = ax.plot_surface(X,Y,z, cmap=cm.Greens)
ax.set_zlim3d(-3.01, 3.01)
plt.colorbar(surf, shrink=0.5, aspect=10)
plt.show()

# %% [markdown]
# # Lecture 07

# %%
import scipy as sp

arr = sp.array([1, 2, 3])

print(arr)
# Out:
# [1 2 3]

# %%
import scipy as sp           

import numpy as np

np.polyfit is sp.polyfit        # 두 polyfit 함수가 같은 대상을 가리키는지 살펴본다
# Out:
# True

# %%
import scipy.fftpack

np.fft.fft is sp.fftpack.fft
# Out:
# False

# %%
from scipy import stats
import matplotlib.pyplot as plt

rv = stats.rayleigh(loc=1) # 파라미터를 지정하여 분포 호출, 변수 ‘rv’에 동결
r = rv.rvs(size=3000) # 위의 통계 분포 함수로 확률 변수 생성
x = np.linspace(rv.ppf(0.01), rv.ppf(0.99), 100) #확률밀도 그래프를 위한 100개 점

plt.figure(1)
plt.clf()
plt.plot(x, rv.pdf(x), 'k-', lw=2, label='확률밀도 함수')
plt.hist(r, density =True, histtype='barstacked', alpha=0.5)
plt.xlabel('값')
plt.ylabel('분포도')
plt.show()

# %%
mpl.rcdefaults()

# %%
from scipy.fftpack import fft # scipy와는 별도로 import해야 함


Fs = 500 # 샘플링 주파수
T=1/Fs # 샘플링 간격
L = 2**14 # 신호의 길이(샘플링 수)
t = sp.arange(L)*T # 시간 벡터
y = np.sin(2*np.pi*30*t) + 5*sp.randn(t.size) # 신호 생성

Y = sp.fftpack.fft(y, L)/L  # FFT 적용
f = (Fs/L)*sp.arange(L/2+1)   # 주파수 벡터를 구함

#원래의 시계열 데이터와 FFT로 주파수 분석을 거친 결과를 그래프로 그리기
plt.figure(1)
plt.subplot(2, 1, 1)
plt.plot(t, y, color = 'orange')
plt.xlabel('time [s]')
plt.ylabel('value')
plt.subplot(2, 1, 2)
plt.plot(f, 2*abs(Y[:L//2+1]))
plt.xlabel('frequency [Hz]')
plt.ylabel('|Y(f)|')
plt.show()
# Out:
#   File "<ipython-input-51-68ca337fa5b0>", line 19
#     \vskip 1em
#               ^
# SyntaxError: unexpected character after line continuation character

# %%
from scipy import signal # scipy와 별도로 import해야 한다.

s1 = sp.signal.lti([1], [1, 1]) # 선형 시스템을 정의

w, mag, phase = sp.signal.bode(s1) # bode 함수를 이용한 분석

# 보드 플롯 그리기
plt.figure(1)
plt.subplot(2, 1, 1)
plt.semilogx(w, mag)
plt.xlabel('frequency [rad/s]')
plt.ylabel('gain [dB]')
plt.subplot(2, 1, 2)
plt.semilogx(w, phase)
plt.xlabel('frequency [rad/s]')
plt.ylabel('phase [deg]')
plt.box('on')
plt.show()
# Out:
# C:\Users\renz\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import scipy.interpolate as ipl 
# 보간으로 근사할 함수를 정의
def f(x):
    return (x-7)*(x-2)*(x+0.2)*(x-4)

# 정답 데이터 생성(틱 크기 0.1)
x = np.linspace(0, 8, 81)
y = np.array(list(map(f,x)))

# 보간 대상 데이터 생성(틱 크기 1)
x0 = np.arange(9)
y0 = np.array(list(map(f,x0)))

# 보간 함수를 설정 
f_linear = ipl.interp1d(x0, y0, bounds_error=False) # 선형
f_cubic = ipl.interp1d(x0, y0, kind='cubic', bounds_error=False)  # 3차 스플라인

# 보간 처리 실행
y1 = f_linear(x)
y2 = f_cubic(x)

# 보간 처리한 데이터와 정답 데이터의 비교를 위해 그래프 그리기
plt.figure(1)
plt.clf()
plt.plot(x, y, 'k-', label='original func')
plt.plot(x0, y0, 'bo', label='before ipl', markersize=10)
plt.plot(x, y1, 'r:', label='linear', linewidth=4)
plt.plot(x, y2, 'y--', label='cubic', linewidth=4, alpha=0.7)
plt.legend(loc='best') 
plt.xlabel('x')
plt.ylabel('y')
plt.grid('on') 
plt.show()
# Out:
# C:\Users\renz\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
